# %% [markdown]
# ## PYTHON ISMAGS Syntax
#
# ```python
# python cli.py [-h] [-f FOLDER] -l LINK_TYPES -n NETWORKS -m MOTIF_DESCRIPTION -o OUTPUT
# ```
#
# - **Folder** is the path containing network files.
# - **LINK_TYPES** are separated by commas e.g. \"A u t t\" or \"A u t t,B d t t\"
# - **NETWORKS** are separated by commas e.g. file1.txt or file1.txt,file2.txt
# - **MOTIF_DESCRIPTION** e.g. AA0A00 is a 3-star where all the connections are of type 'A'
# - **OUTPUT** is the output file name.
# - Note: at the command line type 'python cli.py -h' to obtain the above information.

# %% [markdown]
# # First Small Example
#
# 3-STAR with hub node distinct from the spokes and edges of one type
#
# Plotted below is the motif which is color-coded by node and edge type.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

motif1_img = mpimg.imread('images/motif1.png')
plt.imshow(motif1_img)

# %%
# %run cli/cli.py -f 'data/' -l "A d t t" -n 'graph1_Ad.txt' -m AA0A00 -o 'graph1.out'
# Out:
# INFO:__main__:Creating link types...
# INFO:__main__:Reading in networks...
# INFO:network.network:Read: data/graph1_Ad.txt | Links: 7
# INFO:network.network:Number of Nodes: 9
# INFO:network.network:Number of Links: 7
# INFO:__main__:Creating motif data structure...
# INFO:algorithm.motif_finder:Initializing ISMAGS MotifFinder...
# INFO:algorithm.motif_finder:Performing motif search...
# INFO:algorithm.motif_finder:Completed motif search in 0.001153 seconds
# INFO:algorithm.motif_finder:Found 1 instances of AA0A00 motif
# INFO:motifs.motif:Writing motif instances to `graph1.out`

# %% [markdown]
# ## Second Example
# 3-STAR with one spoke node distinct from rest and edges of two types

# %%
motif2_img = mpimg.imread('images/motif2.png')
plt.imshow(motif2_img)

# %%
# %run cli/cli.py -f 'data/' -l "A d t t,B u t t" -n 'graph2_Ad.txt,graph2_Bu.txt' -m AB0B00 -o 'graph2.out'
# Out:
# INFO:__main__:Creating link types...
# INFO:__main__:Reading in networks...
# INFO:network.network:Read: data/graph2_Ad.txt | Links: 22
# INFO:network.network:Read: data/graph2_Bu.txt | Links: 95
# INFO:network.network:Number of Nodes: 153
# INFO:network.network:Number of Links: 117
# INFO:__main__:Creating motif data structure...
# INFO:algorithm.motif_finder:Initializing ISMAGS MotifFinder...
# INFO:algorithm.motif_finder:Performing motif search...
# INFO:algorithm.motif_finder:Completed motif search in 0.001260 seconds
# INFO:algorithm.motif_finder:Found 5 instances of AB0B00 motif
# INFO:motifs.motif:Writing motif instances to `graph2.out`

# %% [markdown]
# ## Third Example
#
# Ensemble with all distinct node types and two edge types

# %%
motif3_img = mpimg.imread('images/motif3.png')
plt.imshow(motif3_img)

# %%
# %run cli/cli.py -f 'data/' -l "A d t t,B d t t,C d t t,D d t t,E d t t,F d t t" \
-n 'graph3_Ad.txt,graph3_Bd.txt,graph3_Cd.txt,graph3_Dd.txt,graph3_Ed.txt,graph3_Fd.txt' \
-m AB00C00F0000E0000D000 -o 'graph3.out'
# Out:
# INFO:__main__:Creating link types...
# INFO:__main__:Reading in networks...
# INFO:network.network:Read: data/graph3_Ad.txt | Links: 796
# INFO:network.network:Read: data/graph3_Bd.txt | Links: 371
# INFO:network.network:Read: data/graph3_Cd.txt | Links: 475
# INFO:network.network:Read: data/graph3_Dd.txt | Links: 160
# INFO:network.network:Read: data/graph3_Ed.txt | Links: 282
# INFO:network.network:Read: data/graph3_Fd.txt | Links: 349
# INFO:network.network:Number of Nodes: 1980
# INFO:network.network:Number of Links: 2433
# INFO:__main__:Creating motif data structure...
# INFO:algorithm.motif_finder:Initializing ISMAGS MotifFinder...
# INFO:algorithm.motif_finder:Performing motif search...
# INFO:algorithm.motif_finder:Completed motif search in 0.089268 seconds
# INFO:algorithm.motif_finder:Found 13098 instances of AB00C00F0000E0000D000 motif
# INFO:motifs.motif:Writing motif instances to `graph3.out`

# %% [markdown]
# ## Fourth Example
#
# Ensemble with many edge types

# %%
motif4_img = mpimg.imread('images/motif4.png')
plt.imshow(motif4_img)

# %%
# %run cli/cli.py -f 'data/' -l "A d t t,B d t t,C d t t,D u t t" \
-n 'graph4_Ad.txt,graph4_Bd.txt,graph4_Cd.txt,graph4_Du.txt' \
-m ABDC00 -o 'graph4.out'
# Out:
# INFO:__main__:Creating link types...
# INFO:__main__:Reading in networks...
# INFO:network.network:Read: data/graph4_Ad.txt | Links: 1281
# INFO:network.network:Read: data/graph4_Bd.txt | Links: 1251
# INFO:network.network:Read: data/graph4_Cd.txt | Links: 1275
# INFO:network.network:Read: data/graph4_Du.txt | Links: 641
# INFO:network.network:Number of Nodes: 1000
# INFO:network.network:Number of Links: 4448
# INFO:__main__:Creating motif data structure...
# INFO:algorithm.motif_finder:Initializing ISMAGS MotifFinder...
# INFO:algorithm.motif_finder:Performing motif search...
# INFO:algorithm.motif_finder:Completed motif search in 0.016034 seconds
# INFO:algorithm.motif_finder:Found 30 instances of ABDC00 motif
# INFO:motifs.motif:Writing motif instances to `graph4.out`

# %% [markdown]
# ## Fifth Example
#
# Searching in a Multi-graph network (more than one connection between nodes)

# %%
motif5_img = mpimg.imread('images/motif5.png')
plt.imshow(motif5_img)

# %%
# %run cli/cli.py -f 'data/' -l "A d t t,B d t t,C d t t" \
-n 'graph5_Ad.txt,graph5_Bd.txt,graph5_Cd.txt' \
-m AB0C00 -o 'graph5.out'
# Out:
# INFO:__main__:Creating link types...
# INFO:__main__:Reading in networks...
# INFO:network.network:Read: data/graph5_Ad.txt | Links: 74
# INFO:network.network:Read: data/graph5_Bd.txt | Links: 48
# INFO:network.network:Read: data/graph5_Cd.txt | Links: 22
# INFO:network.network:Number of Nodes: 107
# INFO:network.network:Number of Links: 144
# INFO:__main__:Creating motif data structure...
# INFO:algorithm.motif_finder:Initializing ISMAGS MotifFinder...
# INFO:algorithm.motif_finder:Performing motif search...
# INFO:algorithm.motif_finder:Completed motif search in 0.001462 seconds
# INFO:algorithm.motif_finder:Found 18 instances of AB0C00 motif
# INFO:motifs.motif:Writing motif instances to `graph5.out`
